# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# file folder
# file name
# file path
file_location="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\Visadataset - Visadataset.csv"
pd.read_csv(file_location)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
file_path="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\bank - bank.csv"
pd.read_csv(file_path)    # if data is not alligned properly so write like this 
                          # pd.read_csv(file_path,sep=";") separatoris based on our data if sometimes : .....etc
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
file_path="C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\files\\bank - bank.csv"
pd.read_csv(file_path, header=None)  # Header will be removed
# Out:
#        0              1        2          3        4        5        6     7   \
# 0     age            job  marital  education  default  balance  housing  loan
# 1      30     unemployed  married    primary       no     1787       no    no
# 2      33       services  married  secondary       no     4789      yes   yes
# 3      35     management   single   tertiary       no     1350      yes    no
# 4      30     management  married   tertiary       no     1476      yes   yes
# ...   ...            ...      ...        ...      ...      ...      ...   ...
# 4517   33       services  married  secondary       no     -333      yes    no
# 4518   57  self-employed  married   tertiary      yes    -3313      yes   yes
# 4519   57     technician  married  secondary       no      295       no    no
# 4520   28    blue-collar  married  secondary       no     1137       no    no
# 4521   44   entrepreneur   single   tertiary       no     1136      yes   yes
#
# ...

# %%
- for excel 
- pd.read_excel()

# %% [markdown]
# - How to create a data frame
# - How to add columns
# - How to add rows
# - How to drop columns
# - How to drop rows
# - How to save the Dataframe

# %% [markdown]
# **Method-1**

# %% [markdown]
# **Create a data frame uisng list**

# %%
Names=["Ramesh","Suresh","Satish"]
Age=[20,25,30]
pd.DataFrame(zip(Names,Age))
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  25
# 2  Satish  30

# %% [markdown]
# **Update the column labels**

# %%
# Adding columns labels
Names=["Ramesh","Suresh","Satish"]
Age=[20,25,30]
pd.DataFrame(zip(Names,Age),
            columns=["Names","Age"])
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30

# %% [markdown]
# **Update the lables of rows**

# %%
# adding rows labels(index)
Names=["Ramesh","Suresh","Satish"]
Age=[20,25,30]
pd.DataFrame(zip(Names,Age),
            columns=["Names","Age"],
            index=["A","B","C"])
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   25
# C  Satish   30

# %%
Names=["Ramesh","Suresh","Satish"]
Age=[20,25,30]
pd.DataFrame(zip(Names,Age),
            columns=["Names","Age"],
            index=[10,11,12])
# Out:
#      Names  Age
# 10  Ramesh   20
# 11  Suresh   25
# 12  Satish   30

# %%
Names=["Ramesh","Suresh","Satish"]
Age=[20,25,30]
df1=pd.DataFrame(zip(Names,Age),
            columns=["Names","Age"],
            index=["A","B","C"])
df1
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   25
# C  Satish   30

# %%
df1['Names']
# Out:
# A    Ramesh
# B    Suresh
# C    Satish
# Name: Names, dtype: object

# %% [markdown]
# **Update the names in the  column**

# %%
# Update the names in the  column 
df1['Names']=["Greeshma","Pradeep","Surya"]

# %%
df1
# Out:
#       Names  Age
# A  Greeshma   20
# B   Pradeep   25
# C     Surya   30

# %% [markdown]
# **Create a one more column**

# %%
# Create a one more column
df1['City']=["Delhi","Hyderabad","Benguluru"]

# %%
df1
# Out:
#       Names  Age       City
# A  Greeshma   20      Delhi
# B   Pradeep   25  Hyderabad
# C     Surya   30  Benguluru

# %% [markdown]
# **Add a new rows**

# %%
df1.loc[3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:345, in RangeIndex.get_loc(self, key)
#     344 try:
# --> 345     return self._range.index(new_key)
#     346 except ValueError as err:
#
# ValueError: 3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df1.loc[3]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
# ...

# %%
# Add a new rows
# Change the index A B C to 0 1 2
Names=["Ramesh","Suresh","Satish"]
Age=[20,25,30]
df1=pd.DataFrame(zip(Names,Age),
            columns=["Names","Age"])
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30

# %%
df1.loc[3]=["Charan",25]

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# 3  Charan   25

# %%
df1.loc[4]=["Sanju",25]

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# 3  Charan   25
# 4   Sanju   25

# %%
df1['City']=["Delhi","Hyderabad","Benguluru","Chennai","Pune"]

# %%
df1
# Out:
#     Names  Age       City
# 0  Ramesh   20      Delhi
# 1  Suresh   25  Hyderabad
# 2  Satish   30  Benguluru
# 3  Charan   25    Chennai
# 4   Sanju   25       Pune

# %%
df1.loc["A"]=["Ganga",26,"Vizag"]

# %%
df1
# Out:
#     Names  Age       City
# 0  Ramesh   20      Delhi
# 1  Suresh   25  Hyderabad
# 2  Satish   30  Benguluru
# 3  Charan   25    Chennai
# 4   Sanju   25       Pune
# A   Ganga   26      Vizag

# %% [markdown]
# **Drop the column**

# %% [markdown]
# - Axis=1  is the reference the columns
# - Axis=0 is the reference the rows
# - the result you want to overwrite or save in another table

# %%
# the result is over write
df1.drop("City",axis=1)
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# 3  Charan   25
# 4   Sanju   25
# A   Ganga   26

# %%
# the result is save in another name

# %%
df2=df1.drop("City",axis=1)

# %%
df2
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# 3  Charan   25
# 4   Sanju   25
# A   Ganga   26

# %%
df1.drop("City",axis=1,inplace=True)

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# A   Ganga   26

# %% [markdown]
# **Drop a row**

# %%
df1.drop(3,axis=0,inplace=True)

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# A   Ganga   26

# %%
df1
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# A   Ganga   26

# %% [markdown]
# **Finally save this dataframe in our local**

# %%
# Read the data file in separate folder
#     You need to provide the entire path
# Write the output in separate folder 
#      You need to provide the entire path
# folder locarion + name of the file + Extension
df1.to_csv("C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\Dataframe.csv")

# %%
df1.to_csv("C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\Dataframe.csv")

# %%
# First read the data
pd.read_csv("C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\Dataframe.csv")
# Out:
#   Unnamed: 0   Names  Age
# 0          0  Ramesh   20
# 1          1  Suresh   25
# 2          2  Satish   30
# 3          A   Ganga   26

# %%
# in this extra 	Unnamed is there 
# we need to avoid that
df1.to_csv("C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\Dataframe.csv",index=False)
# check in the files

# %%
# Read it agin 
pd.read_csv("C:\\Users\\Greeshma\\OneDrive\\Naresh IT\\Dataframe.csv")
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30
# 3   Ganga   26

# %%
# Save in the same file
df1.to_csv("DataFrame1.csv")

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Greeshma\\OneDrive\\Naresh IT'

# %% [markdown]
# # Method-2 #

# %% [markdown]
# **Create a dataframe using dictionary**

# %%
d1={"Names":["Ramesh","Suresh","Satish"],
   "Age":[20,25,30]}
d1
# Out:
# {'Names': ['Ramesh', 'Suresh', 'Satish'], 'Age': [20, 25, 30]}

# %%
# Keys consider as  a column name
# Vlaues are consider as rows
pd.DataFrame(d1)
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   25
# 2  Satish   30

# %% [markdown]
# # Method-3 #

# %%
# Creating empty data frame
df1=pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import random
even_list=[]
for i in range(10):
    num=random.randint(20,50)
    if num%2==0:
        even_list.append(num)
even_list
# Out:
# [40, 20, 22, 42, 46]

# %%
df1['Even']=even_list

# %%
df1
# Out:
#    Even
# 0    40
# 1    20
# 2    22
# 3    42
# 4    46

# %%
import random
even_list=[]
odd_list=[]
for i in range(10):
    num=random.randint(20,50)
    if num%2==0:
        even_list.append(num)
    else:
        odd_list.append(num)
print(even_list)
print(odd_list)
# Out:
# [26, 38, 40, 26, 30]
# [29, 31, 31, 37, 21]

# %%
df3=pd.DataFrame()
df3
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df3["Even Numbers"]=even_list

# %%
df3
# Out:
#    Even Numbers
# 0            26
# 1            38
# 2            40
# 3            26
# 4            30

# %%
df3["Odd Numbers"]=odd_list

# %%
df3
# Out:
#    Even Numbers  Odd Numbers
# 0            26           29
# 1            38           31
# 2            40           31
# 3            26           37
# 4            30           21
